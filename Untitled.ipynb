# %%
import numpy as np                  #' Numpy 
import pandas as pd                 #' DataFrames manipulation    

from sys import exit as exit
from warnings import warn as warning
from scipy.stats import entropy as entropy

from entropytriangle.auxfunc import *

# %%
from entropytriangle import *

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/glass/glass.data', names = ['ID','Ri','Na','Mg','Al','Si','K','Ca','Ba','Fe','Type'])
df = df.drop(['ID'],axis = 1)
df = df.drop(['Type'],axis = 1)

# %%
edf = sentropies_df(df)
# Out:
# 71
# /Users/jaime.de.los.rios/Documents/GitHub/entropytriangle/entropytriangle/sentropies.py:112: UserWarning: Discretizing data from X DataFrame before entropy calculation!
#   warning("Discretizing data from X DataFrame before entropy calculation!")
# /Users/jaime.de.los.rios/Documents/GitHub/entropytriangle/entropytriangle/auxfunc.py:39: UserWarning: Discretizing data!
#   warning("Discretizing data!")

# %%
edf
# Out:
#                H_Uxi      H_Pxi  DeltaH_Pxi      M_Pxi    VI_Pxi
# Name
# Ri          5.357552   4.632134    0.725418   4.632134  0.000000
# Na          5.285402   4.753305    0.532097   4.753305  0.000000
# Mg          5.169925   4.052585    1.117340   4.052585  0.000000
# Al          5.700440   5.117036    0.583404   5.117036  0.000000
# Si          5.491853   4.820165    0.671688   4.810819  0.009346
# K           4.087463   2.871426    1.216037   2.871426  0.000000
# Ca          5.321928   4.440858    0.881071   4.440858  0.000000
# Ba          4.643856   1.447729    3.196127   1.447729  0.000000
# Fe          5.000000   2.407724    2.592276   2.407724  0.000000
# AGGREGATE  46.058419  34.542962   11.515457  34.533616  0.009346

# %%
p = etplot(edf)

# %%
p
# Out:
# [array([13.5400939, 86.4599061,  0.       ]),
#  array([10.06729666, 89.93270334,  0.        ]),
#  array([21.61230219, 78.38769781,  0.        ]),
#  array([10.23436424, 89.76563576,  0.        ]),
#  array([12.23063233, 87.59919206,  0.17017561]),
#  array([29.75041347, 70.24958653,  0.        ]),
#  array([16.5554759, 83.4445241,  0.       ]),
#  array([68.82485646, 31.17514354,  0.        ]),
#  array([51.84551164, 48.15448836,  0.        ]),
#  array([2.50018507e+01, 7.49778581e+01, 2.02911749e-02])]
