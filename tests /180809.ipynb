# %%
from entropytriangle import *

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', names = ['sepal length','sepal width','petal length','petal width','class'])
df = df.drop(['class'],axis = 1)


df1 = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.data', names = ['Sample code number','Clump Thickness','Uniformity of Cell Size','Uniformity of Cell Shape','Marginal Adhesion','Single Epithelial Cell Size','Bare Nuclei','Bland Chromatin','Normal Nucleoli','Mitoses','Class'])
df1 = df1.drop(['Sample code number'],axis = 1)
df1 = df1.drop(['Class'],axis = 1)

df2 = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/glass/glass.data', names = ['ID','Ri','Na','Mg','Al','Si','K','Ca','Ba','Fe','Type'])
df2 = df2.drop(['ID'],axis = 1)
df2 = df2.drop(['Type'],axis = 1)

# %%
a = list()
a.append(df)
a.append(df1)
a.append(df2)
names = list(['Iris', 'Breast Cancer','Glass'])

total = sentropieslist(a,names, returntype= 1)

etplotjoint(total,names,gridl=20 ,s_mk=300)
# Out:
# /Users/jaime.de.los.rios/Documents/GitHub/entropytriangle/entropytriangle/sentropies.py:112: UserWarning: Discretizing data from X DataFrame before entropy calculation!
#   warning("Discretizing data from X DataFrame before entropy calculation!")
# /Users/jaime.de.los.rios/Documents/GitHub/entropytriangle/entropytriangle/auxfunc.py:39: UserWarning: Discretizing data!
#   warning("Discretizing data!")
# 50
# 233
# 71

# %%
total
# Out:
# [                  H_Uxi      H_Pxi  DeltaH_Pxi      M_Pxi    VI_Pxi
#  Name
#  sepal length   5.129283   4.822018    0.307265   4.723652  0.098366
#  sepal width    4.523562   4.011710    0.511852   3.958376  0.053333
#  petal length   5.209453   4.786520    0.422933   4.733187  0.053333
#  petal width    4.459432   4.065663    0.393769   3.998996  0.066667
#  AGGREGATE     19.321730  17.685911    1.635819  17.414212  0.271699,
#                                   H_Uxi      H_Pxi  DeltaH_Pxi      M_Pxi  \
#  Name
#  Clump Thickness               3.321928   3.043769    0.278159   2.132048
#  Uniformity of Cell Size       3.321928   2.335876    0.986052   2.250165
#  Uniformity of Cell Shape      3.321928   2.494164    0.827764   2.245182
#  Marginal Adhesion             3.321928   2.195697    1.126231   2.039599
#  Single Epithelial Cell Size   3.321928   2.286494    1.035434   2.045416
#  Bare Nuclei                   3.459432   2.104255    1.355177   1.933975
#  Bland Chromatin               3.321928   2.766158    0.555770   2.155283
#  Normal Nucleoli               3.321928   2.046419    1.275509   1.948689
#  Mitoses                       3.169925   1.110333    2.059592   1.068736
#  AGGREGATE                    29.882853  20.383164    9.499689  17.819093
#
#                                 VI_Pxi
#  Name
#  Clump Thickness              0.911721
#  Uniformity of Cell Size      0.085711
#  Uniformity of Cell Shape     0.248982
#  Marginal Adhesion            0.156097
#  Single Epithelial Cell Size  0.241079
#  Bare Nuclei                  0.170280
#  Bland Chromatin              0.610876
#  Normal Nucleoli              0.097730
#  Mitoses                      0.041596
#  AGGREGATE                    2.564071  ,
#                 H_Uxi      H_Pxi  DeltaH_Pxi      M_Pxi    VI_Pxi
#  Name
#  Ri          5.357552   4.632134    0.725418   4.632134  0.000000
#  Na          5.285402   4.753305    0.532097   4.753305  0.000000
#  Mg          5.169925   4.052585    1.117340   4.052585  0.000000
#  Al          5.700440   5.117036    0.583404   5.117036  0.000000
#  Si          5.491853   4.820165    0.671688   4.810819  0.009346
#  K           4.087463   2.871426    1.216037   2.871426  0.000000
#  Ca          5.321928   4.440858    0.881071   4.440858  0.000000
#  Ba          4.643856   1.447729    3.196127   1.447729  0.000000
#  Fe          5.000000   2.407724    2.592276   2.407724  0.000000
#  AGGREGATE  46.058419  34.542962   11.515457  34.533616  0.009346]

# %%
df1

e = list()
for i in range(len(df1.columns)):
    e.append(len(df1[df1.columns[i]].unique()))

# %%
etplot(edf,gridl=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-df80250be80d> in <module>()
# ----> 1 etplot(edf,gridl=20)
#
# NameError: name 'edf' is not defined

# %%
import numpy as np

# %%
a = np.log2(e)

# %%
a

# %%
edf = sentropies_df(df1)

# %%
edf

# %%
w= w/w[0]

# %%
w*100
# Out:
# H_Uxi         100.000000
# H_Pxi          91.626584
# DeltaH_Pxi      8.373416
# M_Pxi          64.181046
# VI_Pxi         27.445538
# Name: Clump Thickness, dtype: float64

# %%
from entropytriangle.coordsentropic import entcoords

# %%
points = entcoords(edf)

# %%
points
# Out:
# [array([ 8.37341609, 64.1810458 , 27.44553811]),
#  array([29.68312158, 67.73670894,  2.58016947]),
#  array([24.91818804, 67.58672108,  7.49509089]),
#  array([33.9029452 , 61.39805651,  4.69899829]),
#  array([31.16966848, 61.57314322,  7.2571883 ]),
#  array([39.17339488, 55.90441841,  4.92218671]),
#  array([16.7303389 , 64.88047532, 18.38918578]),
#  array([38.39666156, 58.66137849,  2.94195995]),
#  array([64.97290247, 33.71487686,  1.31222067]),
#  array([31.78976537, 59.62982478,  8.58040984])]

# %%
df = discretization(df)
# Out:
# 50
# /Users/jaime.de.los.rios/Documents/GitHub/entropytriangle/entropytriangle/auxfunc.py:32: UserWarning: Discretizing data!
#   warning("Discretizing data!")

# %%
edf = sentropies_df(df1)
# Out:
# /Users/jaime.de.los.rios/Documents/GitHub/entropytriangle/entropytriangle/sentropies.py:109: UserWarning: Discretizing data from X DataFrame before entropy calculation!
#   warning("Discretizing data from X DataFrame before entropy calculation!")
# /Users/jaime.de.los.rios/Documents/GitHub/entropytriangle/entropytriangle/auxfunc.py:32: UserWarning: Discretizing data!
#   warning("Discretizing data!")
# 233

# %%
2.302585 * 1.442695
# Out:
# 3.3219278665750003

# %%
etplot(edf,gridl=20)

# %%
edf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-cb56c76a3d40> in <module>()
# ----> 1 edf
#
# NameError: name 'edf' is not defined
