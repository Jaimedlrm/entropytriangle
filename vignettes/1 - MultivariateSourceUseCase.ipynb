# %% [markdown]
# # Multivariate Source Use Case (Single DataFrameCase)

# %% [markdown]
# In this vignette I will represent a use case of the Source Multivariate Entropy Triangle with some individual Databases

# %% [markdown]
# ### Importing Libraries

# %% [markdown]
# As the functions for the entopies measures are stored in other domain, first we will need to access those modules with the functions and the import all the necessary functions

# %%
# Bring your packages onto the path
import sys,os
sys.path.append(os.path.abspath(os.path.join('..'))) #'entropytriangle main directory

# %%
from entropytriangle import * #importing all modules necessary for the plotting

# %% [markdown]
# ### Dowloading a set of Databases

# %%
#df = pd.read_csv('Arthitris.csv',delimiter=',',index_col='Unnamed: 0')
df = pd.read_csv('Breast_data.csv',delimiter=',',index_col='Unnamed: 0').drop(['Sample code number'],axis = 1).replace('?',np.nan) # in this DB the missing values are represented as '?' 
#df = pd.read_csv('Glass.csv',delimiter=',')
#df = pd.read_csv('Ionosphere.csv',delimiter=',')
#df = pd.read_csv('Iris.csv',delimiter=',',index_col='Id')
#df = pd.read_csv('Wine.csv',delimiter=',').drop(['Wine'],axis = 1)

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 699 entries, 1 to 699
# Data columns (total 10 columns):
# Clump Thickness                699 non-null int64
# Uniformity of Cell Size        699 non-null int64
# Uniformity of Cell Shape       699 non-null int64
# Marginal Adhesion              699 non-null int64
# Single Epithelial Cell Size    699 non-null int64
# Bare Nuclei                    683 non-null float64
# Bland Chromatin                699 non-null int64
# Normal Nucleoli                699 non-null int64
# Mitoses                        699 non-null int64
# Class                          699 non-null object
# dtypes: float64(1), int64(8), object(1)
# memory usage: 60.1+ KB

# %%
df.head(10)
# Out:
#     Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 1                 5                        1                         1
# 2                 5                        4                         4
# 3                 3                        1                         1
# 4                 6                        8                         8
# 5                 4                        1                         1
# 6                 8                       10                        10
# 7                 1                        1                         1
# 8                 2                        1                         2
# 9                 2                        1                         1
# 10                4                        2                         1
#
#     Marginal Adhesion  Single Epithelial Cell Size  Bare Nuclei  \
# 1                   1                            2          1.0
# 2                   5                            7         10.0
# 3                   1                            2          2.0
# 4                   1                            3          4.0
# 5                   3                            2          1.0
# 6                   8                            7         10.0
# 7                   1                            2         10.0
# 8                   1                            2          1.0
# 9                   1                            2          1.0
# 10                  1                            2          1.0
#
#     Bland Chromatin  Normal Nucleoli  Mitoses      Class
# 1                 3                1        1     benign
# 2                 3                2        1     benign
# 3                 3                1        1     benign
# 4                 3                7        1     benign
# 5                 3                1        1     benign
# 6                 9                7        1  malignant
# 7                 3                1        1     benign
# 8                 3                1        1     benign
# 9                 1                1        5     benign
# 10                2                1        1     benign

# %% [markdown]
# ### Discretizing the Data before entropy calculation

# %% [markdown]
# We have defined a function for discretizing a hole dataset, the function divides de entries in
# "NROWS(DF)^(1/3)" equally sized spaces, and turn the data types in "categories"

# %%
df = discretization(df)
# Out:
# /Users/jaime.de.los.rios/Documents/GitHub/entropytriangle/entropytriangle/auxfunc.py:39: UserWarning: Discretizing data!
#   warning("Discretizing data!")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 699 entries, 1 to 699
# Data columns (total 10 columns):
# Clump Thickness                699 non-null category
# Uniformity of Cell Size        699 non-null category
# Uniformity of Cell Shape       699 non-null category
# Marginal Adhesion              699 non-null category
# Single Epithelial Cell Size    699 non-null category
# Bare Nuclei                    683 non-null category
# Bland Chromatin                699 non-null category
# Normal Nucleoli                699 non-null category
# Mitoses                        699 non-null category
# Class                          699 non-null category
# dtypes: category(10)
# memory usage: 15.8 KB

# %%
df.head(10)
# Out:
#    Clump Thickness Uniformity of Cell Size Uniformity of Cell Shape  \
# 1                3                       0                        0
# 2                3                       2                        2
# 3                1                       0                        0
# 4                4                       6                        6
# 5                2                       0                        0
# 6                6                       7                        7
# 7                0                       0                        0
# 8                0                       0                        0
# 9                0                       0                        0
# 10               2                       0                        0
#
#    Marginal Adhesion Single Epithelial Cell Size Bare Nuclei Bland Chromatin  \
# 1                  0                           0         0.0               1
# 2                  3                           5         7.0               1
# 3                  0                           0         0.0               1
# 4                  0                           1         2.0               1
# 5                  1                           0         0.0               1
# 6                  6                           5         7.0               7
# 7                  0                           0         7.0               1
# 8                  0                           0         0.0               1
# 9                  0                           0         0.0               0
# 10                 0                           0         0.0               0
#
#    Normal Nucleoli Mitoses Class
# 1                0       0     0
# 2                0       0     0
# 3                0       0     0
# 4                5       0     0
# 5                0       0     0
# 6                5       0     1
# 7                0       0     0
# 8                0       0     0
# 9                0       3     0
# 10               0       0     0

# %% [markdown]
# ### Source Entropies Measures calculation

# %% [markdown]
# Once we have our data discretized, we will start by calculating the values of the entropies for the posterior plots

# %%
'''
As the database is previosly discretized we won´t need the values of the bins
'Type variable select the entropy calculation:'
    Total: Total source entropy decomposition (CPx)
    Dual : Dual source entropy decomposition (DPx instead of CPx)
'''

edf = sentropies_df(df , type = 'total' , base = 2)

# %%
edf
# Out:
#                                  H_Uxi      H_Pxi  DeltaH_Pxi      M_Pxi  \
# Name
# Clump Thickness               3.000000   2.736921    0.263079   1.700498
# Uniformity of Cell Size       3.000000   1.995827    1.004173   1.919573
# Uniformity of Cell Shape      3.000000   2.099060    0.900940   1.888126
# Marginal Adhesion             3.000000   1.799080    1.200920   1.638452
# Single Epithelial Cell Size   3.000000   1.963974    1.036026   1.832804
# Bare Nuclei                   3.169925   1.691657    1.478268   1.505832
# Bland Chromatin               3.000000   2.270245    0.729755   1.787030
# Normal Nucleoli               3.000000   1.701462    1.298538   1.645996
# Mitoses                       3.000000   0.833258    2.166742   0.807694
# Class                         1.000000   0.929318    0.070682   0.929318
# AGGREGATE                    28.169925  18.020802   10.149123  15.655323
#
#                                VI_Pxi
# Name
# Clump Thickness              1.036423
# Uniformity of Cell Size      0.076254
# Uniformity of Cell Shape     0.210933
# Marginal Adhesion            0.160628
# Single Epithelial Cell Size  0.131170
# Bare Nuclei                  0.185825
# Bland Chromatin              0.483215
# Normal Nucleoli              0.055466
# Mitoses                      0.025564
# Class                        0.000000
# AGGREGATE                    2.365479

# %% [markdown]
# ### Source Entropies Entropy Triangle Plotting

# %% [markdown]
# The last step will be plotting the values calculated previously. The coordinates will be calculated multiplying the normalized values needed by the scale used for plotting the triangle, and will appear behind the triangle plot for comparission

# %%
etplot(edf,s_mk=170, pltscale=18)
# Out:
# [array([ 8.76929928, 56.68326446, 34.54743626]),
#  array([33.47242476, 63.98576927,  2.54180597]),
#  array([30.03133996, 62.93754696,  7.03111308]),
#  array([40.03068141, 54.61505886,  5.35425973]),
#  array([34.53419597, 61.09345981,  4.37234422]),
#  array([46.63417203, 47.50371544,  5.86211253]),
#  array([24.3251502 , 59.56766811, 16.10718169]),
#  array([43.28459343, 54.86653176,  1.84887481]),
#  array([72.22474222, 26.92313394,  0.85212384]),
#  array([ 7.06820628, 92.93179372,  0.        ]),
#  array([36.02822215, 55.57459981,  8.39717805])]
